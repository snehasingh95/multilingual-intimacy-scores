# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 26.0 MB/s
# ...
#      |████████████████████████████████| 182 kB 49.9 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 37.2 MB/s
# ...

# %%
import pandas as pd
import numpy as np

import torch
from torch import nn
import numpy as np
from transformers import AutoModel, AutoTokenizer

from torch.optim import Adam
from tqdm import tqdm

# %%
datapath = '/content/train_copy.csv'
df = pd.read_csv(datapath)
df.head()
# Out:
#                                                 text  label  normalized label  \
# 0  wearing a fake engagement ring so guys won’t a...    1.8             -0.28
# 1                               Bees vs. Wasps. http    1.0             -0.60
# 2               Here is a nice equation: 0+0-0-0+0=0    1.0             -0.60
# 3               @user @user Enjoy each new day!😊🇨🇦🐞🐭    1.6             -0.36
# 4  I can be having a perfectly good day then I th...    1.6             -0.36
#
#   language
# 0  English
# 1  English
# 2  English
# 3  English
# 4  English

# %%
df = df.loc[df['language'] == "Chinese"]
df.head()
# Out:
#                                                    text  label  \
# 7895                        @liu_xiaoyuan 红外测温仪在室外误差极大。   1.40
# 7896  @user ok, 你的这些所谓举例有跟你指控间谍罪有直接关系嘛？ 你可以对人/事有意见，但...   1.20
# 7897  不滿意&gt; &lt;昨晚糾結了很久 但畫了這麼久也不想棄掉他們 所以還是把劣作放上來 http   1.60
# 7898  《正信摧邪 - 禁止謗佛者造惡業》 末法時期學佛修行的多，除南無羌佛座下解脫成就眾多弟子之外...   1.20
# 7899                          我可以叫你宝宝吗 我看你对我就是这么叫的 http   4.25
#
#       normalized label language
# 7895             -0.44  Chinese
# 7896             -0.52  Chinese
# 7897             -0.36  Chinese
# 7898             -0.52  Chinese
# 7899              0.70  Chinese

# %%
df = df.drop('label', axis=1)
df = df.drop('language', axis=1)
df.head()
# Out:
#                                                    text  normalized label
# 7895                        @liu_xiaoyuan 红外测温仪在室外误差极大。             -0.44
# 7896  @user ok, 你的这些所谓举例有跟你指控间谍罪有直接关系嘛？ 你可以对人/事有意见，但...             -0.52
# 7897  不滿意&gt; &lt;昨晚糾結了很久 但畫了這麼久也不想棄掉他們 所以還是把劣作放上來 http             -0.36
# 7898  《正信摧邪 - 禁止謗佛者造惡業》 末法時期學佛修行的多，除南無羌佛座下解脫成就眾多弟子之外...             -0.52
# 7899                          我可以叫你宝宝吗 我看你对我就是这么叫的 http              0.70

# %%
np.random.seed(112)
df_train, df_validate, df_test = \
              np.split(df.sample(frac=1, random_state=42), 
                       [int(.8*len(df)), int(.9*len(df))])

# %%
print(df_train.shape)
print(df_validate.shape)
print(df_test.shape)
# Out:
# (1276, 2)
# (160, 2)
# (160, 2)

# %%
df_train.to_csv(r'/content/train.txt', header=None, index=None, sep='\t', mode='a')
df_validate.to_csv(r'/content/validate.txt', header=None, index=None, sep='\t', mode='a')
df_test.to_csv(r'/content/test.txt', header=None, index=None, sep='\t', mode='a')
